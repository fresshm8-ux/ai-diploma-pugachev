# %% [markdown]
# # Занятие 4. Типы данных и проектирование таблиц
#
# ## Цель занятия
#
# На прошлых занятиях мы научились:
# - создавать базу данных;
# - создавать таблицу;
# - добавлять данные;
# - получать данные;
# - изменять и удалять записи.
#
# Сегодня важная тема: **как правильно проектировать таблицы**.
#
# К концу занятия студент должен понимать:
#
# - какие бывают типы данных в SQLite;
# - зачем нужен `PRIMARY KEY`;
# - зачем нужен `AUTOINCREMENT`;
# - как выбирать поля таблицы;
# - почему структура таблицы важна для дипломного проекта;
# - как спроектировать таблицу под свою тему.
#
# ---
#
# ## Зачем проектировать таблицы
#
# Таблица — это не просто набор столбцов.
#
# Если таблица плохо спроектирована, потом будет сложно:
# - добавлять данные;
# - искать данные;
# - фильтровать данные;
# - делать аналитику;
# - развивать дипломный проект.
#
# Пример плохой таблицы:
#
# | data |
# |---|
# | Анна, Казань, 20, студент |
#
# Всё лежит в одном столбце. Такую таблицу неудобно анализировать.
#
# Пример хорошей таблицы:
#
# | id | name | city | age | role |
# |---|---|---|---|---|
# | 1 | Анна | Казань | 20 | student |
#
# Каждый признак лежит в отдельном столбце.
#
# ---
#
# ## Основные типы данных в SQLite
#
# | Тип | Что хранит |
# |---|---|
# | INTEGER | целые числа |
# | TEXT | текст |
# | REAL | числа с точкой |
# | NULL | пустое значение |
# | BLOB | бинарные данные |
#
# В этом курсе чаще всего используем:
# - `INTEGER`;
# - `TEXT`;
# - `REAL`.
#
# ---
#
# ## Что такое PRIMARY KEY
#
# `PRIMARY KEY` — это главный уникальный идентификатор записи.
#
# Обычно это поле `id`.
#
# Пример:
#
# ```sql
# id INTEGER PRIMARY KEY AUTOINCREMENT
# ```
#
# Это означает:
# - `id` — номер записи;
# - `PRIMARY KEY` — уникальный ключ;
# - `AUTOINCREMENT` — номер увеличивается автоматически.
#
# ---
#
# ## Почему это важно в реальной жизни
#
# В реальных системах почти у каждой записи есть уникальный номер:
#
# - номер заказа;
# - номер пользователя;
# - номер резюме;
# - номер тренировки;
# - номер товара.
#
# Без `id` сложно точно понимать, какую запись нужно изменить или удалить.
#
# ---
#
# ## Зачем это нужно в дипломе
#
# На этом занятии студент начинает думать как разработчик:
#
# - какие данные хранить;
# - какие поля нужны;
# - какие типы данных выбрать;
# - как таблица будет использоваться в проекте.
#
# Примеры для диплома:
#
# HR:
# - `candidate_id`;
# - `name`;
# - `skills`;
# - `experience_years`;
# - `status`.
#
# Питание:
# - `meal_id`;
# - `product`;
# - `calories`;
# - `protein`;
# - `meal_type`.
#
# Спорт:
# - `workout_id`;
# - `exercise`;
# - `duration_min`;
# - `calories_burned`;
# - `goal`.
#
# ---
#
# ## Связь с GitHub
#
# На этом занятии студент должен сохранить:
#
# - solved-ноутбук;
# - TODO-ноутбук;
# - схему таблицы для своего дипломного проекта;
# - SQL-код создания таблиц.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/lesson-04-table-design
# ```
#
# Рекомендуемый commit:
#
# ```bash
# git add .
# git commit -m "feat: add database table design"
# git push -u origin feature/lesson-04-table-design
# ```

# %% [markdown]
# ## Ячейка 1. Подключаем sqlite3 и создаём базу
#
# Создаём учебную базу `design_lesson04.db`.

# %%
import sqlite3

connection = sqlite3.connect("design_lesson04.db")
cursor = connection.cursor()

print("База данных подключена")
# Out:
# База данных подключена

# %% [markdown]
# ## Ячейка 2. Таблица resumes для HR-проекта

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS resumes (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    full_name TEXT,
    position TEXT,
    experience_years INTEGER,
    city TEXT,
    score REAL
)
""")

connection.commit()

print("Таблица resumes создана")
# Out:
# Таблица resumes создана

# %% [markdown]
# ## Ячейка 3. Таблица meals для проекта питания

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS meals (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    product TEXT,
    meal_type TEXT,
    calories INTEGER,
    protein REAL,
    fat REAL,
    carbs REAL
)
""")

connection.commit()

print("Таблица meals создана")
# Out:
# Таблица meals создана

# %% [markdown]
# ## Ячейка 4. Таблица workouts для спортивного проекта

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS workouts (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    exercise TEXT,
    workout_type TEXT,
    duration_min INTEGER,
    calories_burned INTEGER,
    effort INTEGER
)
""")

connection.commit()

print("Таблица workouts создана")
# Out:
# Таблица workouts создана

# %% [markdown]
# ## Ячейка 5. Смотрим список таблиц в базе
#
# В SQLite есть служебная таблица `sqlite_master`.

# %%
cursor.execute("""
SELECT name FROM sqlite_master
WHERE type = 'table'
""")

tables = cursor.fetchall()

print("Таблицы в базе:")
for table in tables:
    print(table)

assert len(tables) >= 3
# Out:
# Таблицы в базе:
# ('resumes',)
# ('sqlite_sequence',)
# ('meals',)
# ('workouts',)

# %% [markdown]
# ## Ячейка 6. Добавляем данные в таблицу resumes

# %%
cursor.execute(
    "INSERT INTO resumes (full_name, position, experience_years, city, score) VALUES (?, ?, ?, ?, ?)",
    ("Анна Смирнова", "Python Developer", 2, "Казань", 87.5)
)

cursor.execute(
    "INSERT INTO resumes (full_name, position, experience_years, city, score) VALUES (?, ?, ?, ?, ?)",
    ("Иван Петров", "Data Analyst", 1, "Москва", 78.0)
)

connection.commit()

print("Резюме добавлены")
# Out:
# Резюме добавлены

# %% [markdown]
# ## Ячейка 7. Добавляем данные в таблицу meals

# %%
cursor.execute(
    "INSERT INTO meals (product, meal_type, calories, protein, fat, carbs) VALUES (?, ?, ?, ?, ?, ?)",
    ("Овсянка", "breakfast", 350, 12.5, 6.0, 60.0)
)

cursor.execute(
    "INSERT INTO meals (product, meal_type, calories, protein, fat, carbs) VALUES (?, ?, ?, ?, ?, ?)",
    ("Курица", "lunch", 450, 35.0, 10.0, 25.0)
)

connection.commit()

print("Данные питания добавлены")
# Out:
# Данные питания добавлены

# %% [markdown]
# ## Ячейка 8. Добавляем данные в таблицу workouts

# %%
cursor.execute(
    "INSERT INTO workouts (exercise, workout_type, duration_min, calories_burned, effort) VALUES (?, ?, ?, ?, ?)",
    ("Бег", "cardio", 40, 420, 7)
)

cursor.execute(
    "INSERT INTO workouts (exercise, workout_type, duration_min, calories_burned, effort) VALUES (?, ?, ?, ?, ?)",
    ("Приседания", "strength", 30, 250, 8)
)

connection.commit()

print("Тренировки добавлены")
# Out:
# Тренировки добавлены

# %% [markdown]
# ## Ячейка 9. Проверяем данные из всех таблиц

# %%
for table_name in ["resumes", "meals", "workouts"]:
    print("\nТаблица:", table_name)
    cursor.execute(f"SELECT * FROM {table_name}")
    rows = cursor.fetchall()
    for row in rows:
        print(row)
    assert len(rows) >= 1
# Out:
# Таблица: resumes
# (1, 'Анна Смирнова', 'Python Developer', 2, 'Казань', 87.5)
# (2, 'Иван Петров', 'Data Analyst', 1, 'Москва', 78.0)
# (3, 'Анна Смирнова', 'Python Developer', 2, 'Казань', 87.5)
# (4, 'Иван Петров', 'Data Analyst', 1, 'Москва', 78.0)
# (5, 'Анна Смирнова', 'Python Developer', 2, 'Казань', 87.5)
# (6, 'Иван Петров', 'Data Analyst', 1, 'Москва', 78.0)
#
# Таблица: meals
# (1, 'Овсянка', 'breakfast', 350, 12.5, 6.0, 60.0)
# (2, 'Курица', 'lunch', 450, 35.0, 10.0, 25.0)
# (3, 'Овсянка', 'breakfast', 350, 12.5, 6.0, 60.0)
# (4, 'Курица', 'lunch', 450, 35.0, 10.0, 25.0)
# (5, 'Овсянка', 'breakfast', 350, 12.5, 6.0, 60.0)
# (6, 'Курица', 'lunch', 450, 35.0, 10.0, 25.0)
#
# Таблица: workouts
# (1, 'Бег', 'cardio', 40, 420, 7)
# (2, 'Приседания', 'strength', 30, 250, 8)
# (3, 'Бег', 'cardio', 40, 420, 7)
# (4, 'Приседания', 'strength', 30, 250, 8)
# (5, 'Бег', 'cardio', 40, 420, 7)
# (6, 'Приседания', 'strength', 30, 250, 8)

# %% [markdown]
# ## Ячейка 10. Закрываем соединение

# %%
connection.close()

print("Соединение закрыто")
# Out:
# Соединение закрыто

# %% [markdown]
# # Итог занятия 4
#
# Сегодня вы научились:
# - выбирать типы данных для таблиц;
# - использовать `INTEGER`, `TEXT`, `REAL`;
# - создавать таблицы для разных проектов;
# - использовать `PRIMARY KEY AUTOINCREMENT`;
# - думать о структуре будущего дипломного проекта.
#
# ## Что коммитить в GitHub
#
# ```bash
# git add .
# git commit -m "feat: add database table design"
# git push -u origin feature/lesson-04-table-design
# ```
