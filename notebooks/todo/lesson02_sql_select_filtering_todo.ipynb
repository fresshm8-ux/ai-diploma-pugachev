# %% [markdown]
# # Занятие 2. SQL SELECT и фильтрация данных
#
# ## Цель занятия
#
# На прошлом занятии мы создали первую базу данных, таблицу и добавили записи.
#
# Сначала изучите solved-ноутбук с преподавателем. Затем выполните этот TODO-ноутбук самостоятельно и используйте свои данные.
#
# К концу занятия студент должен уметь:
#
# - выполнять `SELECT`;
# - выбирать отдельные столбцы;
# - использовать `WHERE`;
# - применять условия `>`, `<`, `=`;
# - использовать `AND` и `OR`;
# - сортировать данные через `ORDER BY`;
# - ограничивать результат через `LIMIT`.
#
# ---
#
# ## Зачем это нужно в реальной жизни
#
# В реальных приложениях редко нужно показывать все данные сразу.
#
# Примеры:
#
# - интернет-магазин показывает товары дешевле 10 000;
# - HR-система ищет кандидатов из конкретного города;
# - приложение питания ищет продукты с калориями меньше 300;
# - спортивное приложение показывает тренировки длиннее 40 минут;
# - учебная система показывает студентов старше 18 лет.
#
# Для этого нужны SQL-запросы с фильтрацией.
#
# ---
#
# ## Что такое SELECT
#
# `SELECT` — команда SQL для получения данных из таблицы.
#
# Пример:
#
# ```sql
# SELECT * FROM products;
# ```
#
# Означает: получить все столбцы и все строки из таблицы `products`.
#
# ---
#
# ## Что такое WHERE
#
# `WHERE` задаёт условие отбора.
#
# Пример:
#
# ```sql
# SELECT * FROM products WHERE price > 10000;
# ```
#
# Означает: получить только товары дороже 10000.
#
# ---
#
# ## Что такое ORDER BY
#
# `ORDER BY` сортирует данные.
#
# Пример:
#
# ```sql
# SELECT * FROM products ORDER BY price DESC;
# ```
#
# Означает: отсортировать товары по цене от дорогих к дешёвым.
#
# ---
#
# ## Что такое LIMIT
#
# `LIMIT` ограничивает количество строк.
#
# Пример:
#
# ```sql
# SELECT * FROM products LIMIT 3;
# ```
#
# Означает: показать только первые 3 строки.
#
# ---
#
# ## Зачем это нужно в дипломе
#
# В дипломном проекте студенту почти всегда нужно будет:
#
# - искать записи;
# - фильтровать данные;
# - показывать топ результатов;
# - делать простую аналитику;
# - выбирать данные под запрос пользователя.
#
# Например:
#
# - HR: кандидаты по городу, опыту, навыкам;
# - питание: продукты по калориям и категории;
# - спорт: тренировки по цели и длительности;
# - магазин: товары по цене и категории.
#
# ---
#
# ## Связь с GitHub
#
# На этом занятии в проект добавляется логика запросов.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/lesson-02-select-filtering
# ```
#
# Рекомендуемый commit:
#
# ```bash
# git add .
# git commit -m "feat: add select and filtering queries"
# git push -u origin feature/lesson-02-select-filtering
# ```

# %% [markdown]
# ## Ячейка 1. TODO: подключите sqlite3 и создайте базу
#
# Создайте базу данных для своей темы.
#
# Примеры:
# - `hr_lesson02.db`;
# - `nutrition_lesson02.db`;
# - `sport_lesson02.db`;
# - `shop_lesson02.db`.

# %%
# TODO: импортируйте sqlite3

# TODO: создайте connection

# TODO: создайте cursor

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 2. TODO: создайте таблицу
#
# Создайте таблицу под свою тему.
#
# Можно использовать пример `products`:
#
# - id
# - title
# - category
# - price
# - count

# %%
# TODO: создайте таблицу через CREATE TABLE IF NOT EXISTS

# TODO: выполните connection.commit()

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 3. TODO: добавьте тестовые данные
#
# Добавьте минимум 8 записей.
#
# Важно: перед добавлением можно очистить таблицу, чтобы при повторном запуске данные не дублировались.

# %%
# TODO: очистите таблицу

# TODO: создайте список записей

# TODO: добавьте записи через executemany

# TODO: выполните commit

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 4. TODO: SELECT *
#
# Получите все строки из таблицы.

# %%
# TODO: выполните SELECT *

# TODO: получите результат через fetchall()

# TODO: выведите строки через for

# TODO: добавьте assert-проверку количества строк

# %% [markdown]
# ## Ячейка 5. TODO: SELECT отдельных столбцов
#
# Получите только 2–3 нужных столбца.
#
# Например:
# - название и цену;
# - имя и город;
# - упражнение и длительность.

# %%
# TODO: выполните SELECT отдельных столбцов

# TODO: получите результат

# TODO: выведите результат

# %% [markdown]
# ## Ячейка 6. TODO: WHERE с числовым условием
#
# Сделайте фильтр по числовому столбцу.
#
# Примеры:
# - price > 10000;
# - age > 18;
# - calories < 300;
# - duration_min > 40.

# %%
# TODO: выполните SELECT с WHERE и числовым условием

# TODO: получите результат

# TODO: выведите результат

# TODO: добавьте assert

# %% [markdown]
# ## Ячейка 7. TODO: WHERE с текстовым условием
#
# Сделайте фильтр по текстовому столбцу.
#
# Примеры:
# - category = "Техника";
# - city = "Казань";
# - goal = "muscle_gain";
# - status = "new".

# %%
# TODO: выполните SELECT с WHERE и текстовым условием

# TODO: получите результат

# TODO: выведите результат

# %% [markdown]
# ## Ячейка 8. TODO: AND и OR
#
# Сделайте два запроса:
#
# 1. с `AND`;
# 2. с `OR`.
#
# Пример:
#
# ```sql
# WHERE category = ? AND price > ?
# ```
#
# ```sql
# WHERE category = ? OR category = ?
# ```

# %%
# TODO: запрос с AND

# TODO: вывести результат

# TODO: запрос с OR

# TODO: вывести результат

# %% [markdown]
# ## Ячейка 9. TODO: ORDER BY и LIMIT
#
# Отсортируйте данные и покажите только первые 3 строки.
#
# Пример:
#
# ```sql
# ORDER BY price DESC LIMIT 3
# ```

# %%
# TODO: выполните SELECT с ORDER BY и LIMIT

# TODO: получите результат

# TODO: выведите результат

# TODO: assert len(result) == 3

# %% [markdown]
# ## Ячейка 10. TODO: закройте соединение
#
# Закройте соединение с базой данных.

# %%
# TODO: закройте соединение

# TODO: выведите сообщение

# %% [markdown]
# # Итог TODO-задания
#
# Покажите преподавателю:
#
# - свою таблицу;
# - минимум 8 записей;
# - `SELECT *`;
# - `SELECT` отдельных столбцов;
# - `WHERE`;
# - `AND`;
# - `OR`;
# - `ORDER BY`;
# - `LIMIT`.
#
# ## Что коммитить в GitHub
#
# ```bash
# git add .
# git commit -m "feat: complete select filtering todo"
# git push -u origin feature/lesson-02-select-filtering
# ```
