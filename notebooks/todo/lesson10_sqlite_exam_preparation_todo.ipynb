# %% [markdown]
# # Занятие 10. Подготовка проекта с базой данных к экзамену
#
# ## Цель занятия
#
# Это финальное занятие блока по базам данных.
#
# На прошлых занятиях мы изучили:
#
# - что такое база данных;
# - SQLite и `sqlite3`;
# - создание таблиц;
# - `INSERT`, `SELECT`, `UPDATE`, `DELETE`;
# - `WHERE`, `ORDER BY`, `LIMIT`;
# - типы данных;
# - связи таблиц;
# - `FOREIGN KEY`;
# - `JOIN`;
# - SQL-аналитику;
# - Python-функции для работы с БД;
# - мини-проект с sqlite3.
#
# Сначала изучите solved-ноутбук с преподавателем. Затем выполните TODO-ноутбук самостоятельно и подготовьте свой проект к экзамену.
#
# Сегодня задача другая:
#
# > подготовить проект к экзамену так, чтобы его можно было уверенно показать преподавателю.
#
# ---
#
# ## Что значит “проект готов к экзамену”
#
# Проект готов, если студент может показать:
#
# 1. тему проекта;
# 2. структуру проекта;
# 3. базу данных;
# 4. таблицы;
# 5. SQL-запросы;
# 6. Python-функции;
# 7. запуск проекта;
# 8. результат работы;
# 9. GitHub-репозиторий;
# 10. краткое объяснение, зачем проект нужен.
#
# ---
#
# ## Что должен уметь студент на защите
#
# Студент должен уметь сказать:
#
# - какую проблему решает проект;
# - какие данные хранятся в БД;
# - какие таблицы созданы;
# - какие SQL-запросы используются;
# - как Python подключается к SQLite;
# - как проект запускается;
# - какие результаты выводятся;
# - что лежит в GitHub.
#
# ---
#
# ## Связь с реальной жизнью
#
# В реальной разработке важно не только написать код, но и подготовить проект к показу:
#
# - заказчику;
# - преподавателю;
# - работодателю;
# - команде;
# - пользователю.
#
# Если проект нельзя запустить и объяснить, он выглядит незавершённым.
#
# ---
#
# ## Связь с дипломом
#
# Этот урок — репетиция дипломной защиты.
#
# Для диплома студенту нужно будет:
#
# - показать структуру проекта;
# - объяснить архитектуру;
# - показать базу данных;
# - показать SQL;
# - показать результат;
# - показать GitHub;
# - ответить на вопросы.
#
# ---
#
# ## Связь с GitHub
#
# На этом занятии студент приводит репозиторий в порядок:
#
# - проверяет `main`;
# - проверяет ветку занятия;
# - делает commit;
# - делает push;
# - открывает Pull Request;
# - делает merge;
# - проверяет, что в `main` лежит стабильная версия.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/lesson-10-exam-ready
# ```
#
# Commit:
#
# ```bash
# git add .
# git commit -m "docs: prepare sqlite project for exam"
# git push -u origin feature/lesson-10-exam-ready
# ```

# %% [markdown]
# ## Ячейка 1. TODO: подключите sqlite3 и создайте функцию подключения
#
# Создайте базу данных для своего экзаменационного проекта.
#
# Примеры:
# - `my_exam_hr.db`;
# - `my_exam_nutrition.db`;
# - `my_exam_sport.db`;
# - `my_exam_shop.db`.

# %%
# TODO: импортируйте sqlite3

# TODO: напишите функцию get_connection(db_name)

# TODO: создайте connection

# TODO: создайте cursor

# TODO: выведите сообщение

# TODO: assert connection is not None

# %% [markdown]
# ## Ячейка 2. TODO: создайте главную таблицу проекта
#
# Таблица должна соответствовать вашей теме.
#
# Примеры:
# - candidates;
# - meals;
# - workouts;
# - products;
# - student_projects.

# %%
# TODO: напишите функцию create_main_table(connection)

# TODO: CREATE TABLE IF NOT EXISTS

# TODO: используйте id INTEGER PRIMARY KEY AUTOINCREMENT

# TODO: connection.commit()

# TODO: вызовите функцию

# %% [markdown]
# ## Ячейка 3. TODO: очистите таблицу и добавьте данные
#
# Добавьте минимум 5 записей.
#
# Данные должны быть осмысленными и связанными с вашей темой.

# %%
# TODO: напишите функцию clear_table(connection)

# TODO: напишите функцию add_record(...)

# TODO: очистите таблицу

# TODO: добавьте минимум 5 записей

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 4. TODO: получите все записи
#
# Создайте функцию, которая возвращает все записи из таблицы.

# %%
# TODO: напишите функцию get_all_records(connection)

# TODO: SELECT * FROM ваша_таблица

# TODO: fetchall()

# TODO: выведите все записи

# TODO: assert len(records) >= 5

# %% [markdown]
# ## Ячейка 5. TODO: сделайте фильтр
#
# Фильтр должен быть полезным для вашей темы.
#
# Примеры:
# - по статусу;
# - по категории;
# - по городу;
# - по цели;
# - по типу.

# %%
# TODO: напишите функцию find_by_filter(connection, value)

# TODO: SELECT * FROM table WHERE field = ?

# TODO: получите filtered_records

# TODO: выведите filtered_records

# TODO: assert

# %% [markdown]
# ## Ячейка 6. TODO: сделайте среднее значение
#
# Посчитайте среднее по числовому полю.
#
# Примеры:
# - средний score;
# - средние калории;
# - средняя цена;
# - средняя длительность.

# %%
# TODO: напишите функцию get_average_value(connection)

# TODO: SELECT AVG(number_field) FROM ваша_таблица

# TODO: fetchone()

# TODO: выведите результат

# TODO: assert average_value > 0

# %% [markdown]
# ## Ячейка 7. TODO: сделайте отчёт GROUP BY
#
# Создайте аналитический отчёт по группам.
#
# Примеры:
# - количество кандидатов по статусам;
# - количество товаров по категориям;
# - тренировки по типам;
# - питание по meal_type.

# %%
# TODO: напишите функцию get_group_report(connection)

# TODO: SELECT group_field, COUNT(*) FROM table GROUP BY group_field

# TODO: fetchall()

# TODO: выведите отчёт

# TODO: assert len(report) >= 1

# %% [markdown]
# ## Ячейка 8. TODO: сделайте топ-3 записей
#
# Отсортируйте данные по числовому полю и покажите 3 лучшие записи.

# %%
# TODO: напишите функцию get_top_records(connection, limit=3)

# TODO: SELECT ... ORDER BY number_field DESC LIMIT ?

# TODO: fetchall()

# TODO: выведите top_records

# TODO: assert len(top_records) == 3

# %% [markdown]
# ## Ячейка 9. TODO: подготовьте текст README
#
# Сделайте краткий текст README для GitHub.
#
# В README должно быть:
# - название проекта;
# - описание;
# - что умеет проект;
# - как запустить;
# - технологии.

# %%
# TODO: создайте переменную readme_text

# TODO: внутри напишите README для своего проекта

# TODO: print(readme_text)

# TODO: assert "sqlite3" in readme_text или "SQLite" in readme_text

# %% [markdown]
# ## Ячейка 10. TODO: финальная демонстрация проекта
#
# Создайте функцию `show_exam_demo(connection)`.
#
# Она должна вывести:
#
# - все записи;
# - фильтр;
# - среднее значение;
# - отчёт GROUP BY;
# - топ-3;
# - финальное сообщение.

# %%
# TODO: напишите функцию show_exam_demo(connection)

# TODO: вызовите внутри все свои функции

# TODO: красиво выведите результаты

# TODO: вызовите show_exam_demo(connection)

# TODO: connection.close()

# TODO: выведите сообщение, что проект готов к экзамену

# %% [markdown]
# # Итог TODO-задания
#
# Покажите преподавателю:
#
# - тему проекта;
# - базу данных;
# - таблицу;
# - минимум 5 записей;
# - фильтр;
# - среднее значение;
# - отчёт GROUP BY;
# - топ-3;
# - README;
# - финальный сценарий демонстрации.
#
# ## Что коммитить в GitHub
#
# ```bash
# git add .
# git commit -m "docs: complete sqlite exam preparation"
# git push -u origin feature/lesson-10-exam-ready
# ```
#
# После этого:
# - открыть Pull Request;
# - сделать merge в `main`;
# - проверить, что проект запускается из `main`.
