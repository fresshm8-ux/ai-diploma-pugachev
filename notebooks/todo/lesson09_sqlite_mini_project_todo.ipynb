# %% [markdown]
# # Занятие 9. Мини-проект с базой данных sqlite3
#
# ## Цель занятия
#
# На прошлых занятиях мы изучили:
#
# - создание базы данных;
# - создание таблиц;
# - `INSERT`;
# - `SELECT`;
# - `UPDATE`;
# - `DELETE`;
# - `WHERE`;
# - `ORDER BY`;
# - `JOIN`;
# - `GROUP BY`;
# - функции Python для работы с sqlite3.
#
# Сегодня собираем всё вместе в **мини-проект с базой данных**.
#
# ---
#
# ## Главная идея занятия
#
# До этого мы изучали отдельные SQL-команды.
#
# Теперь задача другая:
#
# > собрать маленькое приложение, где Python-функции работают с базой данных как единый проект.
#
# ---
#
# ## Какой мини-проект делаем в solved
#
# Сначала изучите solved-ноутбук с преподавателем. Затем выполните TODO-ноутбук самостоятельно и соберите мини-проект под свою тему.
#
# В solved-ноутбуке делаем мини-проект:
#
# **HR Resume Tracker**
#
# Он умеет:
#
# - создать таблицу кандидатов;
# - добавить кандидатов;
# - показать всех кандидатов;
# - найти кандидатов по статусу;
# - обновить статус кандидата;
# - посчитать аналитику по статусам;
# - показать лучших кандидатов по score.
#
# ---
#
# ## Почему это полезно в реальной жизни
#
# Похожая логика есть в реальных HR-системах:
#
# - кандидат откликнулся;
# - рекрутер смотрит список кандидатов;
# - меняет статус;
# - выбирает лучших;
# - считает аналитику по воронке отбора.
#
# ---
#
# ## Как это связано с дипломом
#
# Это почти готовая логика дипломного проекта.
#
# По такой же схеме можно сделать:
#
# HR:
# - кандидаты;
# - вакансии;
# - статусы;
# - score.
#
# Питание:
# - продукты;
# - приёмы пищи;
# - калории;
# - рекомендации.
#
# Спорт:
# - тренировки;
# - упражнения;
# - длительность;
# - прогресс.
#
# Магазин:
# - товары;
# - заказы;
# - клиенты;
# - выручка.
#
# ---
#
# ## Что должно получиться
#
# После занятия студент должен понимать:
#
# - как собрать SQL-код в функции;
# - как сделать главный сценарий проекта;
# - как показать результат преподавателю;
# - как подготовить проект к экзамену;
# - что переносить из Colab в VS Code.
#
# ---
#
# ## Связь с GitHub
#
# На этом занятии студент должен сохранить:
#
# - solved-ноутбук;
# - TODO-ноутбук;
# - свою базу данных;
# - функции мини-проекта;
# - будущий код для `src/db/`.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/lesson-09-db-mini-project
# ```
#
# Рекомендуемый commit:
#
# ```bash
# git add .
# git commit -m "feat: build sqlite mini project"
# git push -u origin feature/lesson-09-db-mini-project
# ```

# %% [markdown]
# ## Ячейка 1. TODO: подключите sqlite3 и создайте функцию подключения
#
# Создайте функцию `get_connection`.
#
# Выберите имя базы под свою тему:
#
# - `my_hr_project.db`;
# - `my_nutrition_project.db`;
# - `my_sport_project.db`;
# - `my_shop_project.db`.

# %%
# TODO: импортируйте sqlite3

# TODO: напишите функцию get_connection(db_name)

# TODO: создайте connection

# TODO: создайте cursor

# TODO: выведите сообщение

# TODO: assert connection is not None

# %% [markdown]
# ## Ячейка 2. TODO: создайте таблицу проекта
#
# Создайте таблицу под свою тему.
#
# Примеры:
#
# HR:
# - candidates
#
# Питание:
# - meals
#
# Спорт:
# - workouts
#
# Магазин:
# - products

# %%
# TODO: напишите функцию create_project_table(connection)

# TODO: внутри функции выполните CREATE TABLE IF NOT EXISTS

# TODO: connection.commit()

# TODO: вызовите функцию

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 3. TODO: очистите таблицу
#
# Создайте функцию очистки таблицы.
#
# Это нужно, чтобы при повторном запуске Colab данные не дублировались.

# %%
# TODO: напишите функцию clear_table(connection)

# TODO: DELETE FROM ваша_таблица

# TODO: connection.commit()

# TODO: вызовите функцию

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 4. TODO: добавьте записи
#
# Создайте функцию добавления одной записи.
#
# Добавьте минимум 5 записей со своими данными.

# %%
# TODO: напишите функцию add_record(...)

# TODO: используйте INSERT INTO с параметрами ?

# TODO: connection.commit()

# TODO: добавьте минимум 5 записей

# TODO: выведите сообщение

# %% [markdown]
# ## Ячейка 5. TODO: получите все записи
#
# Создайте функцию `get_all_records`.

# %%
# TODO: напишите функцию get_all_records(connection)

# TODO: SELECT * FROM ваша_таблица

# TODO: return cursor.fetchall()

# TODO: получите records

# TODO: выведите записи

# TODO: assert len(records) >= 5

# %% [markdown]
# ## Ячейка 6. TODO: фильтр по статусу/категории/типу
#
# Создайте функцию фильтрации по текстовому полю.
#
# Примеры:
# - status;
# - category;
# - meal_type;
# - workout_type;
# - city.

# %%
# TODO: напишите функцию find_by_field(connection, value)

# TODO: SELECT * FROM table WHERE field = ?

# TODO: получите filtered_records

# TODO: выведите результат

# TODO: assert

# %% [markdown]
# ## Ячейка 7. TODO: UPDATE
#
# Создайте функцию обновления одной записи.
#
# Примеры:
# - обновить статус кандидата;
# - изменить цену товара;
# - изменить длительность тренировки;
# - изменить калории продукта.

# %%
# TODO: напишите функцию update_record(...)

# TODO: UPDATE ... SET ... WHERE ...

# TODO: connection.commit()

# TODO: проверьте изменение через SELECT

# TODO: assert

# %% [markdown]
# ## Ячейка 8. TODO: аналитика GROUP BY
#
# Создайте аналитический отчёт.
#
# Например:
# - количество кандидатов по статусам;
# - количество товаров по категориям;
# - сумма калорий по типам приёма пищи;
# - количество тренировок по типам.

# %%
# TODO: напишите функцию get_group_report(connection)

# TODO: SELECT group_field, COUNT(*) или SUM(...)
# TODO: GROUP BY group_field

# TODO: получите report

# TODO: выведите report

# TODO: assert len(report) >= 1

# %% [markdown]
# ## Ячейка 9. TODO: топ записей
#
# Создайте функцию, которая возвращает топ-3 записи по числовому полю.
#
# Примеры:
# - top кандидатов по score;
# - top товаров по цене;
# - top тренировок по калориям;
# - top продуктов по калориям.

# %%
# TODO: напишите функцию get_top_records(connection, limit=3)

# TODO: SELECT ... ORDER BY number_field DESC LIMIT ?

# TODO: получите top_records

# TODO: выведите top_records

# TODO: assert len(top_records) == 3

# %% [markdown]
# ## Ячейка 10. TODO: финальный сценарий мини-проекта
#
# Создайте функцию `show_project_summary`.
#
# Она должна вывести:
#
# - все записи;
# - фильтр;
# - аналитический отчёт;
# - топ-3 записи.
#
# После этого закройте соединение.

# %%
# TODO: напишите функцию show_project_summary(connection)

# TODO: внутри вызовите свои функции

# TODO: выведите понятный отчёт

# TODO: вызовите show_project_summary(connection)

# TODO: connection.close()

# TODO: выведите сообщение

# %% [markdown]
# # Итог TODO-задания
#
# Покажите преподавателю:
#
# - тему мини-проекта;
# - таблицу;
# - минимум 5 записей;
# - функцию добавления;
# - функцию фильтрации;
# - функцию UPDATE;
# - аналитический отчёт;
# - топ-3 записи;
# - финальный сценарий проекта.
#
# ## Что коммитить в GitHub
#
# ```bash
# git add .
# git commit -m "feat: complete sqlite mini project todo"
# git push -u origin feature/lesson-09-db-mini-project
# ```
